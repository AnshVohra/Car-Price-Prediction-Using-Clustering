# %%
import warnings
warnings.filterwarnings('ignore')

#importing the libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("Cars-Engage.xls")

# %%
df.head()
# Out:
#    Unnamed: 0  Make      Model  Variant Ex-Showroom_Price Displacement  \
# 0           0  Tata  Nano Genx       Xt      Rs. 2,92,667       624 cc
# 1           1  Tata  Nano Genx       Xe      Rs. 2,36,447       624 cc
# 2           2  Tata  Nano Genx  Emax Xm      Rs. 2,96,661       624 cc
# 3           3  Tata  Nano Genx      Xta      Rs. 3,34,768       624 cc
# 4           4  Tata  Nano Genx       Xm      Rs. 2,72,223       624 cc
#
#    Cylinders  Valves_Per_Cylinder              Drivetrain  \
# 0        2.0                  2.0  RWD (Rear Wheel Drive)
# 1        2.0                  2.0  RWD (Rear Wheel Drive)
# 2        2.0                  2.0  RWD (Rear Wheel Drive)
# 3        2.0                  2.0  RWD (Rear Wheel Drive)
# 4        2.0                  2.0  RWD (Rear Wheel Drive)
#
#   Cylinder_Configuration  ... Leather_Wrapped_Steering Automatic_Headlamps  \
# 0                In-line  ...                      NaN                 NaN
# ...

# %%
df.dtypes
# Out:
# Unnamed: 0             int64
# Make                  object
# Model                 object
# Variant               object
# Ex-Showroom_Price     object
#                       ...
# USB_Ports            float64
# Heads-Up_Display      object
# Welcome_Lights        object
# Battery               object
# Electric_Range        object
# Length: 141, dtype: object

# %%
df['Wheelbase'] = df['Wheelbase'].str.replace('mm', '')
df['Wheelbase']
# Out:
# 0       2230
# 1       2230
# 2       2230
# 3       2230
# 4       2230
#         ...
# 1271    2600
# 1272    2600
# 1273    2600
# 1274    2600
# 1275    2780
# Name: Wheelbase, Length: 1276, dtype: object

# %%
df['Displacement'] = df['Displacement'].str.replace('cc', '')
df['Displacement']
# Out:
# 0        624
# 1        624
# 2        624
# 3        624
# 4        624
#         ...
# 1271    1498
# 1272    1498
# 1273    1497
# 1274    1497
# 1275    3200
# Name: Displacement, Length: 1276, dtype: object

# %%
df.rename(columns = {'Ex-Showroom_Price':'Price_Ex'}, inplace = True)

# %%
df['Price_Ex'] = df['Price_Ex'].str.replace(',', '')
df['Price_Ex'] = df['Price_Ex'].str.replace('Rs', '')
df['Price_Ex'] = df['Price_Ex'].str.replace('.', '')
df['Price_Ex']
# Out:
# 0         292667
# 1         236447
# 2         296661
# 3         334768
# 4         272223
#           ...
# 1271     1302000
# 1272     1421000
# 1273     1431000
# 1274     1201000
# 1275     6862560
# Name: Price_Ex, Length: 1276, dtype: object

# %%
df['Price_Ex'].astype('float')
# Out:
# 0        292667.0
# 1        236447.0
# 2        296661.0
# 3        334768.0
# 4        272223.0
#           ...
# 1271    1302000.0
# 1272    1421000.0
# 1273    1431000.0
# 1274    1201000.0
# 1275    6862560.0
# Name: Price_Ex, Length: 1276, dtype: float64

# %%
df['Wheelbase'].astype('float')
# Out:
# 0       2230.0
# 1       2230.0
# 2       2230.0
# 3       2230.0
# 4       2230.0
#          ...
# 1271    2600.0
# 1272    2600.0
# 1273    2600.0
# 1274    2600.0
# 1275    2780.0
# Name: Wheelbase, Length: 1276, dtype: float64

# %%
df['Displacement'].astype('float')
# Out:
# 0        624.0
# 1        624.0
# 2        624.0
# 3        624.0
# 4        624.0
#          ...
# 1271    1498.0
# 1272    1498.0
# 1273    1497.0
# 1274    1497.0
# 1275    3200.0
# Name: Displacement, Length: 1276, dtype: float64

# %%
df.Length
# Out:
# 0       3164 mm
# 1       3164 mm
# 2       3164 mm
# 3       3164 mm
# 4       3164 mm
#          ...
# 1271    4440 mm
# 1272    4440 mm
# 1273    4440 mm
# 1274    4440 mm
# 1275    4900 mm
# Name: Length, Length: 1276, dtype: object

# %%
df['Length'] = df['Length'].str.replace('mm', '')
df['Length']
# Out:
# 0       3164
# 1       3164
# 2       3164
# 3       3164
# 4       3164
#         ...
# 1271    4440
# 1272    4440
# 1273    4440
# 1274    4440
# 1275    4900
# Name: Length, Length: 1276, dtype: object

# %%
df['Length'].astype('float')
# Out:
# 0       3164.0
# 1       3164.0
# 2       3164.0
# 3       3164.0
# 4       3164.0
#          ...
# 1271    4440.0
# 1272    4440.0
# 1273    4440.0
# 1274    4440.0
# 1275    4900.0
# Name: Length, Length: 1276, dtype: float64

# %%
df['Width'] = df['Width'].str.replace('mm', '')
df['Width']
df['Width'].astype('float')
# Out:
# 0       1750.0
# 1       1750.0
# 2       1750.0
# 3       1750.0
# 4       1750.0
#          ...
# 1271    1695.0
# 1272    1695.0
# 1273    1695.0
# 1274    1695.0
# 1275    1875.0
# Name: Width, Length: 1276, dtype: float64

# %%
df.Power
# Out:
# 0        38PS@5500rpm
# 1        38PS@5500rpm
# 2        38PS@5500rpm
# 3        38PS@5500rpm
# 4        38PS@5500rpm
#             ...
# 1271    100PS@3600rpm
# 1272    100PS@3600rpm
# 1273    119PS@6600rpm
# 1274    119PS@6600rpm
# 1275    202ps@3800rpm
# Name: Power, Length: 1276, dtype: object

# %%
new = df["Power"].str.split("@", n = 1, expand = True)

# %%
new
# Out:
#           0        1
# 0      38PS  5500rpm
# 1      38PS  5500rpm
# 2      38PS  5500rpm
# 3      38PS  5500rpm
# 4      38PS  5500rpm
# ...     ...      ...
# 1271  100PS  3600rpm
# 1272  100PS  3600rpm
# 1273  119PS  6600rpm
# 1274  119PS  6600rpm
# 1275  202ps  3800rpm
#
# [1276 rows x 2 columns]

# %%
df["Power"] = new[0]

# %%
df.Power
# Out:
# 0        38PS
# 1        38PS
# 2        38PS
# 3        38PS
# 4        38PS
#         ...
# 1271    100PS
# 1272    100PS
# 1273    119PS
# 1274    119PS
# 1275    202ps
# Name: Power, Length: 1276, dtype: object

# %%
df['Power'] = df['Power'].str.replace('PS', '')
df['Power'] = df['Power'].str.replace('Ps', '')
df['Power'] = df['Power'].str.replace('ps', '')
df['Power'] = df['Power'].str.replace('bhp', '')
df['Power'] = df['Power'].str.replace('hp', '')
df['Power'] = df['Power'].str.replace('HP', '')
df['Power'] = df['Power'].str.replace('NM', '')
df['Power'] = df['Power'].str.replace('Nm', '')
df['Power'] = df['Power'].str.replace('KW', '')
df['Power'] = df['Power'].str.replace('Kw', '')
df['Power'] = df['Power'].str.replace('Kwh', '')
df['Power'] = df['Power'].str.replace('KWH', '')
df['Power'] = df['Power'].str.replace('kW', '')
df['Power'] = df['Power'].str.replace('B', '')
df['Power']
df['Power'].astype('float')
# Out:
# 0        38.0
# 1        38.0
# 2        38.0
# 3        38.0
# 4        38.0
#         ...
# 1271    100.0
# 1272    100.0
# 1273    119.0
# 1274    119.0
# 1275    202.0
# Name: Power, Length: 1276, dtype: float64

# %%
df.shape
# Out:
# (1276, 141)

# %%
df['City_Mileage'] = df['City_Mileage'].str.replace('?', '')
df['City_Mileage'] = df['City_Mileage'].str.replace('km/litre', '')
df['City_Mileage'] = df['City_Mileage'].str.replace(',', '.')
df['City_Mileage']
# Out:
# 0       23.6
# 1       23.6
# 2         NaN
# 3       23.6
# 4       23.6
#         ...
# 1271    22.6
# 1272    22.6
# 1273      18
# 1274    14.3
# 1275    8.25
# Name: City_Mileage, Length: 1276, dtype: object

# %%
new = df["City_Mileage"].str.split("-", n = 1, expand = True)

# %%
new
# Out:
#           0     1
# 0     23.6   None
# 1     23.6   None
# 2       NaN   NaN
# 3     23.6   None
# 4     23.6   None
# ...     ...   ...
# 1271  22.6   None
# 1272  22.6   None
# 1273    18   None
# 1274  14.3   None
# 1275  8.25   None
#
# [1276 rows x 2 columns]

# %%
df['City_Mileage'] = new[0]

# %%
df['City_Mileage'].astype('float')
# Out:
# 0       23.60
# 1       23.60
# 2         NaN
# 3       23.60
# 4       23.60
#         ...
# 1271    22.60
# 1272    22.60
# 1273    18.00
# 1274    14.30
# 1275     8.25
# Name: City_Mileage, Length: 1276, dtype: float64

# %%
df.describe()
# Out:
#         Unnamed: 0    Cylinders  Valves_Per_Cylinder        Doors  \
# count  1276.000000  1210.000000          1174.000000  1272.000000
# mean    637.500000     4.380992             3.977853     4.550314
# std     368.493781     1.660957             0.833763     0.747816
# min       0.000000     2.000000             1.000000     2.000000
# 25%     318.750000     4.000000             4.000000     4.000000
# 50%     637.500000     4.000000             4.000000     5.000000
# 75%     956.250000     4.000000             4.000000     5.000000
# max    1275.000000    16.000000            16.000000     5.000000
#
#        Seating_Capacity  Number_of_Airbags  USB_Ports
# count       1270.000000        1141.000000  29.000000
# mean           5.270079           3.787029   1.793103
# std            1.145231           2.522399   0.773642
# min            2.000000           1.000000   1.000000
# 25%            5.000000           2.000000   1.000000
# ...

# %%
df.info
# Out:
# <bound method DataFrame.info of       Unnamed: 0        Make      Model        Variant  Price_Ex Displacement  \
# 0              0        Tata  Nano Genx             Xt    292667         624
# 1              1        Tata  Nano Genx             Xe    236447         624
# 2              2        Tata  Nano Genx        Emax Xm    296661         624
# 3              3        Tata  Nano Genx            Xta    334768         624
# 4              4        Tata  Nano Genx             Xm    272223         624
# ...          ...         ...        ...            ...       ...          ...
# 1271        1271       Honda       City   Vx Mt Diesel   1302000        1498
# 1272        1272       Honda       City   Zx Mt Diesel   1421000        1498
# 1273        1273       Honda       City  Zx Cvt Petrol   1431000        1497
# 1274        1274       Honda       City   V Cvt Petrol   1201000        1497
# 1275        1275  Mitsubishi    Montero         3.2 At   6862560        3200
#
# ...

# %%
df.Make.unique()
# Out:
# array(['Tata', 'Datsun', 'Renault', 'Maruti Suzuki', 'Hyundai', 'Premier',
#        'Toyota', 'Nissan', 'Volkswagen', 'Ford', 'Mahindra', 'Fiat',
#        'Honda', 'Jeep', 'Isuzu', 'Skoda', 'Audi', nan, 'Dc', 'Mini',
#        'Volvo', 'Jaguar', 'Bmw', 'Land Rover', 'Porsche', 'Lexus',
#        'Maserati', 'Lamborghini', 'Bentley', 'Ferrari', 'Aston Martin',
#        'Bugatti', 'Bajaj', 'Icml', 'Force', 'Mg', 'Kia',
#        'Land Rover Rover', 'Mitsubishi', 'Maruti Suzuki R'], dtype=object)

# %%
sorted(df)
# Out:
# ['12v_Power_Outlet',
#  '3_Point_Seat-Belt_in_Middle_Rear_Seat',
#  'ABS_(Anti-lock_Braking_System)',
#  'ARAI_Certified_Mileage',
#  'ARAI_Certified_Mileage_for_CNG',
#  'ASR_/_Traction_Control',
#  'Adjustable_Headrests',
#  'Adjustable_Steering_Column',
#  'Airbags',
#  'Ambient_Lightning',
#  'Android_Auto',
#  'Apple_CarPlay',
#  'Audiosystem',
#  'Auto-Dimming_Rear-View_Mirror',
#  'Automatic_Headlamps',
#  'Aux-in_Compatibility',
#  'Average_Fuel_Consumption',
#  'Average_Speed',
#  'Basic_Warranty',
#  'Battery',
#  'Bluetooth',
#  'Body_Type',
#  'Boot-lid_Opener',
#  'Boot_Space',
#  'CD_/_MP3_/_DVD_Player',
#  'Cargo/Boot_Lights',
#  'Central_Locking',
#  'Child_Safety_Locks',
#  'Cigarette_Lighter',
#  'City_Mileage',
#  'Clock',
#  'Compression_Ratio',
#  'Cooled_Glove_Box',
#  'Cruise_Control',
#  'Cup_Holders',
#  'Cylinder_Configuration',
#  'Cylinders',
#  'Displacement',
#  'Distance_to_Empty',
#  'Door_Ajar_Warning',
#  'Door_Pockets',
#  'Doors',
# ...

# %%
df.loc[df.duplicated()]
# Out:
# Empty DataFrame
# ...

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Make', 'Model', 'Variant', 'Price_Ex', 'Displacement',
#        'Cylinders', 'Valves_Per_Cylinder', 'Drivetrain',
#        'Cylinder_Configuration',
#        ...
#        'Leather_Wrapped_Steering', 'Automatic_Headlamps', 'Engine_Type',
#        'ASR_/_Traction_Control', 'Cruise_Control', 'USB_Ports',
#        'Heads-Up_Display', 'Welcome_Lights', 'Battery', 'Electric_Range'],
#       dtype='object', length=141)

# %%
df.rename(columns = {'Ex-Showroom_Price':'Price_Ex'}, inplace = True)

# %%
df.head()
# Out:
#    Unnamed: 0  Make      Model  Variant Price_Ex Displacement  Cylinders  \
# 0           0  Tata  Nano Genx       Xt   292667         624         2.0
# 1           1  Tata  Nano Genx       Xe   236447         624         2.0
# 2           2  Tata  Nano Genx  Emax Xm   296661         624         2.0
# 3           3  Tata  Nano Genx      Xta   334768         624         2.0
# 4           4  Tata  Nano Genx       Xm   272223         624         2.0
#
#    Valves_Per_Cylinder              Drivetrain Cylinder_Configuration  ...  \
# 0                  2.0  RWD (Rear Wheel Drive)                In-line  ...
# 1                  2.0  RWD (Rear Wheel Drive)                In-line  ...
# 2                  2.0  RWD (Rear Wheel Drive)                In-line  ...
# 3                  2.0  RWD (Rear Wheel Drive)                In-line  ...
# 4                  2.0  RWD (Rear Wheel Drive)                In-line  ...
#
#   Leather_Wrapped_Steering Automatic_Headlamps Engine_Type  \
# ...

# %%
df.dtypes
# Out:
# Unnamed: 0            int64
# Make                 object
# Model                object
# Variant              object
# Price_Ex             object
#                      ...
# USB_Ports           float64
# Heads-Up_Display     object
# Welcome_Lights       object
# Battery              object
# Electric_Range       object
# Length: 141, dtype: object

# %%
df['Price_Ex'] = df['Price_Ex'].str.replace(',', '')
df['Price_Ex'] = df['Price_Ex'].str.replace('Rs', '')
df['Price_Ex']
# Out:
# 0         292667
# 1         236447
# 2         296661
# 3         334768
# 4         272223
#           ...
# 1271     1302000
# 1272     1421000
# 1273     1431000
# 1274     1201000
# 1275     6862560
# Name: Price_Ex, Length: 1276, dtype: object

# %%
df.dtypes
# Out:
# Unnamed: 0            int64
# Make                 object
# Model                object
# Variant              object
# Price_Ex             object
#                      ...
# USB_Ports           float64
# Heads-Up_Display     object
# Welcome_Lights       object
# Battery              object
# Electric_Range       object
# Length: 141, dtype: object

# %%
df
# Out:
#       Unnamed: 0        Make      Model        Variant  Price_Ex Displacement  \
# 0              0        Tata  Nano Genx             Xt    292667         624
# 1              1        Tata  Nano Genx             Xe    236447         624
# 2              2        Tata  Nano Genx        Emax Xm    296661         624
# 3              3        Tata  Nano Genx            Xta    334768         624
# 4              4        Tata  Nano Genx             Xm    272223         624
# ...          ...         ...        ...            ...       ...          ...
# 1271        1271       Honda       City   Vx Mt Diesel   1302000        1498
# 1272        1272       Honda       City   Zx Mt Diesel   1421000        1498
# 1273        1273       Honda       City  Zx Cvt Petrol   1431000        1497
# 1274        1274       Honda       City   V Cvt Petrol   1201000        1497
# 1275        1275  Mitsubishi    Montero         3.2 At   6862560        3200
#
# ...

# %%
new_kg = df["Kerb_Weight"].str.split("-", n = 1, expand = True)
new_kg
df["Kerb_Weight"] = new_kg[0]

# %%
df['Kerb_Weight'] = df['Kerb_Weight'].str.replace('kg', '')
df['Kerb_Weight']
df['Kerb_Weight'].astype('float')
# Out:
# 0        660.0
# 1        725.0
# 2        710.0
# 3        725.0
# 4        725.0
#          ...
# 1271    1170.0
# 1272    1175.0
# 1273    1107.0
# 1274    1080.0
# 1275    2335.0
# Name: Kerb_Weight, Length: 1276, dtype: float64

# %%
df['Power'] = df['Power'].str.replace('cc', '')
df['Power']
df['Power'].astype('float')
# Out:
# 0        38.0
# 1        38.0
# 2        38.0
# 3        38.0
# 4        38.0
#         ...
# 1271    100.0
# 1272    100.0
# 1273    119.0
# 1274    119.0
# 1275    202.0
# Name: Power, Length: 1276, dtype: float64

# %%
df['Wheelbase'] = df['Wheelbase'].str.replace('mm', '')
df['Wheelbase']
df['Wheelbase'].astype('float')
# Out:
# 0       2230.0
# 1       2230.0
# 2       2230.0
# 3       2230.0
# 4       2230.0
#          ...
# 1271    2600.0
# 1272    2600.0
# 1273    2600.0
# 1274    2600.0
# 1275    2780.0
# Name: Wheelbase, Length: 1276, dtype: float64

# %%
df['Displacement'] = df['Displacement'].str.replace('cc', '')
df['Displacement']
df['Displacement'].astype('float')
# Out:
# 0        624.0
# 1        624.0
# 2        624.0
# 3        624.0
# 4        624.0
#          ...
# 1271    1498.0
# 1272    1498.0
# 1273    1497.0
# 1274    1497.0
# 1275    3200.0
# Name: Displacement, Length: 1276, dtype: float64

# %%
df.head()
# Out:
#    Unnamed: 0  Make      Model  Variant Price_Ex Displacement  Cylinders  \
# 0           0  Tata  Nano Genx       Xt   292667         624         2.0
# 1           1  Tata  Nano Genx       Xe   236447         624         2.0
# 2           2  Tata  Nano Genx  Emax Xm   296661         624         2.0
# 3           3  Tata  Nano Genx      Xta   334768         624         2.0
# 4           4  Tata  Nano Genx       Xm   272223         624         2.0
#
#    Valves_Per_Cylinder              Drivetrain Cylinder_Configuration  ...  \
# 0                  2.0  RWD (Rear Wheel Drive)                In-line  ...
# 1                  2.0  RWD (Rear Wheel Drive)                In-line  ...
# 2                  2.0  RWD (Rear Wheel Drive)                In-line  ...
# 3                  2.0  RWD (Rear Wheel Drive)                In-line  ...
# 4                  2.0  RWD (Rear Wheel Drive)                In-line  ...
#
#   Leather_Wrapped_Steering Automatic_Headlamps Engine_Type  \
# ...

# %%
df.dtypes
# Out:
# Unnamed: 0            int64
# Make                 object
# Model                object
# Variant              object
# Price_Ex             object
#                      ...
# USB_Ports           float64
# Heads-Up_Display     object
# Welcome_Lights       object
# Battery              object
# Electric_Range       object
# Length: 141, dtype: object

# %%
df["Price_Ex"] = df.Price_Ex.astype(float)

# %%
df.dtypes
# Out:
# Unnamed: 0            int64
# Make                 object
# Model                object
# Variant              object
# Price_Ex            float64
#                      ...
# USB_Ports           float64
# Heads-Up_Display     object
# Welcome_Lights       object
# Battery              object
# Electric_Range       object
# Length: 141, dtype: object

# %%
plt.subplot(1,2,1)
plt.title('Car Price Distribution Plot')
sns.distplot(df.Price_Ex)

plt.subplot(1,2,2)
plt.title('Car Price Spread')
sns.boxplot(y=df.Price_Ex)

plt.show()

# %%
print(df.Price_Ex.describe(percentiles = [0.25,0.50,0.75,0.85,0.90,1]))
# Out:
# count    1.276000e+03
# mean     4.596538e+06
# std      1.214735e+07
# min      2.364470e+05
# 25%      7.438760e+05
# 50%      1.060064e+06
# 75%      2.979828e+06
# 85%      6.457835e+06
# 90%      1.017524e+07
# 100%     2.121554e+08
# max      2.121554e+08
# Name: Price_Ex, dtype: float64

# %%
df
# Out:
#       Unnamed: 0        Make      Model        Variant   Price_Ex  \
# 0              0        Tata  Nano Genx             Xt   292667.0
# 1              1        Tata  Nano Genx             Xe   236447.0
# 2              2        Tata  Nano Genx        Emax Xm   296661.0
# 3              3        Tata  Nano Genx            Xta   334768.0
# 4              4        Tata  Nano Genx             Xm   272223.0
# ...          ...         ...        ...            ...        ...
# 1271        1271       Honda       City   Vx Mt Diesel  1302000.0
# 1272        1272       Honda       City   Zx Mt Diesel  1421000.0
# 1273        1273       Honda       City  Zx Cvt Petrol  1431000.0
# 1274        1274       Honda       City   V Cvt Petrol  1201000.0
# 1275        1275  Mitsubishi    Montero         3.2 At  6862560.0
#
#      Displacement  Cylinders  Valves_Per_Cylinder               Drivetrain  \
# 0            624         2.0                  2.0   RWD (Rear Wheel Drive)
# ...

# %%
plt.figure(figsize=(40,10))

plt.subplot(1,3,1)
plt1 = df.Make.value_counts().plot(kind='bar')
plt.title('Companies Histogram')
plt1.set(xlabel = 'Car company', ylabel='Frequency of company')

plt.subplot(1,3,2)
plt1 = df.Fuel_Type.value_counts().plot(kind='bar')
plt.title('Fuel Type Histogram')
plt1.set(xlabel = 'Fuel Type', ylabel='Frequency of fuel type')

plt.subplot(1,3,3)
plt1 = df.Body_Type.value_counts().plot(kind='bar')
plt.title('Car Type Histogram')
plt1.set(xlabel = 'Car Type', ylabel='Frequency of Car type')

plt.show()

# %%
df
# Out:
#       Unnamed: 0        Make      Model        Variant   Price_Ex  \
# 0              0        Tata  Nano Genx             Xt   292667.0
# 1              1        Tata  Nano Genx             Xe   236447.0
# 2              2        Tata  Nano Genx        Emax Xm   296661.0
# 3              3        Tata  Nano Genx            Xta   334768.0
# 4              4        Tata  Nano Genx             Xm   272223.0
# ...          ...         ...        ...            ...        ...
# 1271        1271       Honda       City   Vx Mt Diesel  1302000.0
# 1272        1272       Honda       City   Zx Mt Diesel  1421000.0
# 1273        1273       Honda       City  Zx Cvt Petrol  1431000.0
# 1274        1274       Honda       City   V Cvt Petrol  1201000.0
# 1275        1275  Mitsubishi    Montero         3.2 At  6862560.0
#
#      Displacement  Cylinders  Valves_Per_Cylinder               Drivetrain  \
# 0            624         2.0                  2.0   RWD (Rear Wheel Drive)
# ...

# %%
plt.figure(figsize=(20,8))

plt.subplot(1,2,1)
plt.title('Cylinder Configuration Histogram')
sns.countplot(df.Cylinder_Configuration, palette=("Blues_d"))

plt.subplot(1,2,2)
plt.title('Cylinder Configuration vs Price')
sns.boxplot(x=df.Cylinder_Configuration, y=df.Price_Ex, palette=("PuBuGn"))

plt.show()

df_Cylinder = pd.DataFrame(df.groupby(['Cylinder_Configuration'])['Price_Ex'].mean().sort_values(ascending = False))
df_Cylinder.plot.bar(figsize=(8,6))
plt.title('Cylinder Configuration vs Average Price')
plt.show()

# %%
plt.figure(figsize=(25, 6))

df_MakeVsPrice = pd.DataFrame(df.groupby(['Make'])['Price_Ex'].mean().sort_values(ascending = False))
df_MakeVsPrice.plot.bar()
plt.title('Company Name vs Average Price')
plt.show()

df_FuelVsPrice = pd.DataFrame(df.groupby(['Fuel_Type'])['Price_Ex'].mean().sort_values(ascending = False))
df_FuelVsPrice.plot.bar()
plt.title('Fuel Type vs Average Price')
plt.show()

df_BodyVsPrice = pd.DataFrame(df.groupby(['Body_Type'])['Price_Ex'].mean().sort_values(ascending = False))
df_FuelVsPrice.plot.bar()
plt.title('Car Type vs Average Price')
plt.show()

# %%
plt.figure(figsize=(15,5))

plt.subplot(1,2,1)
plt.title('Door Number Histogram')
sns.countplot(df.Doors, palette=("plasma"))

plt.subplot(1,2,2)
plt.title('Door Number vs Price')
sns.boxplot(x=df.Doors, y=df.Price_Ex, palette=("plasma"))

plt.show()

# %%
plt.figure(figsize=(25, 6))
df_DoorVsPrice = pd.DataFrame(df.groupby(['Doors'])['Price_Ex'].mean().sort_values(ascending = False))
df_DoorVsPrice.plot.bar()
plt.title('Doors vs Average Price')
plt.show()

# %%
def plot_count(x,fig):
    plt.subplot(4,2,fig)
    plt.title(x+' Histogram')
    sns.countplot(df[x],palette=("magma"))
    plt.subplot(4,2,(fig+1))
    plt.title(x+' vs Price')
    sns.boxplot(x=df[x], y=df.Price_Ex, palette=("magma"))
    
plt.figure(figsize=(15,20))

plot_count('Engine_Location', 1)
plot_count('Cylinders', 3)
plot_count('Fuel_System', 5)
plot_count('Drivetrain', 7)

plt.tight_layout()

# %%
def pp(x,y,z):
    sns.pairplot(df, x_vars=[x,y,z], y_vars='Price_Ex',size=4, aspect=1, kind='scatter')
    plt.show()


pp('Wheelbase', 'City_Mileage', 'Highway_Mileage')

# %%
df.columns.all
# Out:
# <bound method Index.all of Index(['Unnamed: 0', 'Make', 'Model', 'Variant', 'Price_Ex', 'Displacement',
#        'Cylinders', 'Valves_Per_Cylinder', 'Drivetrain',
#        'Cylinder_Configuration',
#        ...
#        'Leather_Wrapped_Steering', 'Automatic_Headlamps', 'Engine_Type',
#        'ASR_/_Traction_Control', 'Cruise_Control', 'USB_Ports',
#        'Heads-Up_Display', 'Welcome_Lights', 'Battery', 'Electric_Range'],
#       dtype='object', length=141)>

# %%
cars_lr = df[['Price_Ex', 'Fuel_Type','Body_Type', 'Drivetrain','Wheelbase',
                  'Kerb_Weight', 'Cylinder_Configuration', 'Cylinders', 'Displacement', 'Power', 
                    'City_Mileage', 'Length','Width']]
cars_lr.head()
# Out:
#    Price_Ex Fuel_Type  Body_Type              Drivetrain Wheelbase  \
# 0  292667.0    Petrol  Hatchback  RWD (Rear Wheel Drive)     2230
# 1  236447.0    Petrol  Hatchback  RWD (Rear Wheel Drive)     2230
# 2  296661.0       CNG  Hatchback  RWD (Rear Wheel Drive)     2230
# 3  334768.0    Petrol  Hatchback  RWD (Rear Wheel Drive)     2230
# 4  272223.0    Petrol  Hatchback  RWD (Rear Wheel Drive)     2230
#
#   Kerb_Weight Cylinder_Configuration  Cylinders Displacement Power  \
# 0        660                 In-line        2.0         624     38
# 1        725                 In-line        2.0         624     38
# 2        710                 In-line        2.0         624     38
# 3        725                 In-line        2.0         624     38
# 4        725                 In-line        2.0         624     38
#
#   City_Mileage Length  Width
# 0        23.6   3164   1750
# 1        23.6   3164   1750
# 2          NaN  3164   1750
# 3        23.6   3164   1750
# ...

# %%
sns.pairplot(cars_lr)
plt.show()

# %%
df
# Out:
#       Unnamed: 0        Make      Model        Variant   Price_Ex  \
# 0              0        Tata  Nano Genx             Xt   292667.0
# 1              1        Tata  Nano Genx             Xe   236447.0
# 2              2        Tata  Nano Genx        Emax Xm   296661.0
# 3              3        Tata  Nano Genx            Xta   334768.0
# 4              4        Tata  Nano Genx             Xm   272223.0
# ...          ...         ...        ...            ...        ...
# 1271        1271       Honda       City   Vx Mt Diesel  1302000.0
# 1272        1272       Honda       City   Zx Mt Diesel  1421000.0
# 1273        1273       Honda       City  Zx Cvt Petrol  1431000.0
# 1274        1274       Honda       City   V Cvt Petrol  1201000.0
# 1275        1275  Mitsubishi    Montero         3.2 At  6862560.0
#
#      Displacement  Cylinders  Valves_Per_Cylinder               Drivetrain  \
# 0            624         2.0                  2.0   RWD (Rear Wheel Drive)
# ...

# %%
from sklearn.model_selection import train_test_split

np.random.seed(0)
df_train, df_test = train_test_split(cars_lr, train_size = 0.7, test_size = 0.3, random_state = 100)

# %%
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler()
num_vars = ['Wheelbase', 'Kerb_Weight', 'Displacement', 'Power','City_Mileage','Length','Width','Price_Ex']
df_train[num_vars] = scaler.fit_transform(df_train[num_vars])

# %%
df_train.head()
# Out:
#       Price_Ex Fuel_Type  Body_Type               Drivetrain  Wheelbase  \
# 73    0.001690    Petrol  Hatchback  FWD (Front Wheel Drive)   0.300505
# 1033  0.019716    Diesel      Sedan   RWD (Rear Wheel Drive)   0.505051
# 510   0.003093    Petrol        SUV  FWD (Front Wheel Drive)   0.332323
# 46    0.001009    Petrol  Hatchback  FWD (Front Wheel Drive)   0.282828
# 976   0.005302    Diesel        SUV  FWD (Front Wheel Drive)   0.388889
#
#       Kerb_Weight Cylinder_Configuration  Cylinders  Displacement     Power  \
# 73       0.071677                In-line        4.0      0.142028  0.048398
# 1033     0.432233                In-line        4.0      0.237091  0.122699
# 510           NaN                In-line        3.0      0.142154  0.066803
# 46            NaN                In-line        4.0      0.128014  0.038855
# 976           NaN                In-line        NaN      0.179397  0.070211
#
#       City_Mileage    Length     Width
# ...

# %%
df_train.describe()
# Out:
#          Price_Ex   Wheelbase  Kerb_Weight   Cylinders  Displacement  \
# count  893.000000  880.000000   642.000000  845.000000    882.000000
# mean     0.021535    0.401838     0.319491    4.373964      0.224119
# std      0.056382    0.107186     0.211960    1.615178      0.128953
# min      0.000000    0.000000     0.000000    2.000000      0.000000
# 25%      0.002650    0.318182     0.156494    4.000000      0.142154
# 50%      0.004323    0.383838     0.247176    4.000000      0.180028
# 75%      0.014348    0.457071     0.460469    4.000000      0.243277
# max      1.000000    1.000000     1.000000   16.000000      1.000000
#
#             Power  City_Mileage      Length       Width
# count  893.000000    510.000000  893.000000  884.000000
# mean     0.097573      0.002486    0.465285    0.524653
# std      0.088986      0.044259    0.139837    0.154666
# min      0.000000      0.000000    0.000000    0.000000
# 25%      0.048398      0.000361    0.371257    0.422319
# ...

# %%
#Correlation using heatmap
plt.figure(figsize = (30, 25))
sns.heatmap(df_train.corr(), annot = True, cmap="YlGnBu")
plt.show()

# %%
#Dividing data into X and y variables
y_train = df_train.pop('Price_Ex')
X_train = df_train

# %%
# !pip install statsmodels==0.13.2 --user
# Out:
# ...
# WARNING: Ignoring invalid distribution -pencv-python (c:\users\ansh\appdata\local\programs\python\python38\lib\site-packages)
# WARNING: Ignoring invalid distribution -pencv-python (c:\users\ansh\appdata\local\programs\python\python38\lib\site-packages)
# WARNING: Ignoring invalid distribution -pencv-python (c:\users\ansh\appdata\local\programs\python\python38\lib\site-packages)
# WARNING: Ignoring invalid distribution -pencv-python (c:\users\ansh\appdata\local\programs\python\python38\lib\site-packages)
# WARNING: Ignoring invalid distribution -pencv-python (c:\users\ansh\appdata\local\programs\python\python38\lib\site-packages)
# WARNING: Ignoring invalid distribution -pencv-python (c:\users\ansh\appdata\local\programs\python\python38\lib\site-packages)
# WARNING: You are using pip version 21.3.1; however, version 22.0.4 is available.
# You should consider upgrading via the 'C:\Users\Ansh\AppData\Local\Programs\Python\Python38\python.exe -m pip install --upgrade pip' command.

# %%
#RFE
from sklearn.feature_selection import RFE
from sklearn.linear_model import LinearRegression
import statsmodels.api as sm 
from statsmodels.stats.outliers_influence import variance_inflation_factor
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-73-67c4aec68900> in <module>
#       2 from sklearn.feature_selection import RFE
#       3 from sklearn.linear_model import LinearRegression
# ----> 4 import statsmodels.api as sm
#       5 from statsmodels.stats.outliers_influence import variance_inflation_factor
#
# c:\users\ansh\appdata\local\programs\python\python38\lib\site-packages\statsmodels\api.py in <module>
#     103     families,
#     104 )
# --> 105 from .graphics import api as graphics
#     106 from .graphics.gofplots import ProbPlot, qqline, qqplot, qqplot_2samples
#     107 from .imputation.bayes_mi import MI, BayesGaussMI
#
# c:\users\ansh\appdata\local\programs\python\python38\lib\site-packages\statsmodels\graphics\api.py in <module>
#       4 from .correlation import plot_corr, plot_corr_grid
#       5 from .factorplots import interaction_plot
# ...
